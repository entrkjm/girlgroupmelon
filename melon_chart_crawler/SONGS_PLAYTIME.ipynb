# %%
#This program is oriented to processing girlgroup songs' playtime

import pandas as pd
import numpy as np
import xlwings as xw
import time
from selenium import webdriver

# %%
df = pd.read_excel('melon_year_top100_2005-2023.xlsx')
df
# Out:
#       period  ranking   song_id                 song_name    song_genre  \
# 0       2005        1    711627                       죄와벌           발라드
# 1       2005        2    732512                       겁쟁이          록/메탈
# 2       2005        3    837567                     사랑했나봐          록/메탈
# 3       2005        4    711626                       살다가           발라드
# 4       2005        5    711628                      광(狂)           발라드
# ...      ...      ...       ...                       ...           ...
# 1893    2023       96  31343875                       첫사랑  인디음악, 포크/블루스
# 1894    2023       97  35668899                   딱 10CM만      R&B/Soul
# 1895    2023       98  36595401  잘 지내자, 우리 (여름날 우리 X 로이킴)           NaN
# 1896    2023       99  36430774                   Allergy            댄스
# 1897    2023      100  36518341                  나에게 그대만이           NaN
#
#            artist_id             artist_name artist_activity_type  album_id  \
# ...

# %%
df[(df['artist_activity_type'] == '그룹|여성')]
# Out:
#       period  ranking   song_id          song_name song_genre artist_id  \
# 13      2005       14    847132            체념 後(후)   R&B/Soul    105803
# 28      2005       29    733379         Super Star         댄스    101487
# 42      2005       43    847126                 여자   R&B/Soul    105803
# 43      2005       44    985472          Happiness   R&B/Soul    174997
# 86      2005       87    985474          그래도 살아가겠지   R&B/Soul    174997
# ...      ...      ...       ...                ...        ...       ...
# 1864    2023       67  35485544             Cookie         댄스   3114174
# 1867    2023       70  35383397  그때 그 순간 그대로 (그그그)        발라드   3110856
# 1883    2023       86  36599949          New Jeans        NaN   3114174
# 1889    2023       92  36266615  Love Me Like This         댄스   3070786
# 1896    2023       99  36430774            Allergy         댄스   2137482
#
#        artist_name artist_activity_type  album_id                   album_name
# ...

# %%
songs

# %%
driver = webdriver.Chrome('C:/Users/rlawh/chromedriver-win64/chromedriver.exe')
driver.get("http://www.google.com/")
